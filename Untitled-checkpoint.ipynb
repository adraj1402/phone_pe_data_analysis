# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df_State_Txn_and_Users=pd.read_excel('./phonepe-pulse_raw-data_q12018-to-q22021-v0-1-5-1720351752.xlsx',sheet_name='State_Txn and Users')

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
df_State_TxnSplit=pd.read_excel('./phonepe-pulse_raw-data_q12018-to-q22021-v0-1-5-1720351752.xlsx',sheet_name='State_TxnSplit')

# %%
df_State_TxnSplit
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018        1         Merchant payments
# 3     Andaman & Nicobar Islands  2018        1        Financial Services
# 4     Andaman & Nicobar Islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
df_State_DeviceData=pd.read_excel('./phonepe-pulse_raw-data_q12018-to-q22021-v0-1-5-1720351752.xlsx',sheet_name='State_DeviceData')

# %%
df_State_DeviceData
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
df_District_Txn_and_Users=pd.read_excel('./phonepe-pulse_raw-data_q12018-to-q22021-v0-1-5-1720351752.xlsx',sheet_name='District_Txn and Users')

# %%
df_District_Demographics=pd.read_excel('./phonepe-pulse_raw-data_q12018-to-q22021-v0-1-5-1720351752.xlsx',sheet_name='District Demographics')

# %%
df_District_Demographics
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
df_District_Demographics.dtypes
# Out:
# State              object
# District           object
# Headquarters       object
# Population          int64
# Area (sq km)      float64
# Density             int64
# Code               object
# Alternate Name     object
# dtype: object

# %%
df_District_Txn_and_Users.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# District             object
# Code                 object
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
df_District_Txn_and_Users.isnull().sum()
# Out:
# State                0
# Year                 0
# Quarter              0
# District             0
# Code                28
# Transactions         0
# Amount (INR)         0
# ATV (INR)            4
# Registered Users     0
# App Opens            0
# dtype: int64

# %%
df_District_Demographics.isnull().sum()
# Out:
# State             0
# District          0
# Headquarters      0
# Population        0
# Area (sq km)      0
# Density           0
# Code              0
# Alternate Name    0
# dtype: int64

# %%
df_State_DeviceData.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Brand                object
# Registered Users      int64
# Percentage          float64
# dtype: object

# %%
df_State_DeviceData.isnull().sum()
# Out:
# State               0
# Year                0
# Quarter             0
# Brand               0
# Registered Users    0
# Percentage          0
# dtype: int64

# %%
df_State_Txn_and_Users.dtypes
# Out:
# State                object
# Year                  int64
# Quarter               int64
# Transactions          int64
# Amount (INR)        float64
# ATV (INR)           float64
# Registered Users      int64
# App Opens             int64
# dtype: object

# %%
def category(x): 
	
        if x < 1900:
            return 'LOW'
        
        elif x > 3000: 
            return 'HIGH'
            
        else : 
            return 'MODERATE'

# %%
df_State_Txn_and_Users['categorised_column']=df_State_Txn_and_Users['ATV (INR)'].apply(category)

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens categorised_column
# ...

# %%
df_State_Txn_and_Users.isnull().sum()
# Out:
# State                 0
# Year                  0
# Quarter               0
# Transactions          0
# Amount (INR)          1
# ATV (INR)             0
# Registered Users      0
# App Opens             0
# categorised_column    0
# dtype: int64

# %%
lolo=df_State_Txn_and_Users['Amount (INR)'].isnull()

# %%
df_State_Txn_and_Users.loc[lolo]
# Out:
#              State  Year  Quarter  Transactions  Amount (INR)  ATV (INR)  \
# 26  Andhra Pradesh  2021        1     289747970           NaN        0.0
#
#     Registered Users  App Opens categorised_column
# 26          18363733  957709447                LOW

# %%
Ap_amt_mean = df_State_Txn_and_Users['Amount (INR)'].mean()

# %%
lolo1=(df_State_Txn_and_Users['State']=='Andhra Pradesh')&(df_State_Txn_and_Users['Amount (INR)'].isnull())

# %%
df_State_Txn_and_Users.loc[lolo1,'Amount (INR)']=Ap_amt_mean

# %%
df_State_Txn_and_Users.isnull().sum()
# Out:
# State                 0
# Year                  0
# Quarter               0
# Transactions          0
# Amount (INR)          0
# ATV (INR)             0
# Registered Users      0
# App Opens             0
# categorised_column    0
# dtype: int64

# %%
df_State_Txn_and_Users.loc[[26]]
# Out:
#              State  Year  Quarter  Transactions  Amount (INR)  ATV (INR)  \
# 26  Andhra Pradesh  2021        1     289747970  7.083332e+10        0.0
#
#     Registered Users  App Opens categorised_column
# 26          18363733  957709447                LOW

# %%
df_State_TxnSplit.isnull().sum()
# Out:
# State               0
# Year                0
# Quarter             0
# Transaction Type    0
# Transactions        0
# Amount (INR)        0
# ATV (INR)           0
# dtype: int64

# %%
df_District_Demographics.describe()
# Out:
#          Population  Area (sq km)       Density
# count  7.420000e+02    742.000000    742.000000
# mean   1.668555e+06   4395.373120    838.512129
# std    1.458849e+06   4254.676124   2754.406896
# min    0.000000e+00      0.000000      0.000000
# 25%    6.530815e+05   2039.750000    198.000000
# 50%    1.322359e+06   3402.500000    353.000000
# 75%    2.297440e+06   5432.750000    686.250000
# max    1.008285e+07  45652.000000  36155.000000

# %%
df_District_Txn_and_Users.describe()
# Out:
#                Year       Quarter  Transactions  Amount (INR)     ATV (INR)  \
# count  10248.000000  10248.000000  1.024800e+04  1.024800e+04  10244.000000
# mean    2019.285714      2.357143  2.003607e+06  3.542311e+09   1909.796545
# std        1.030208      1.108924  9.613466e+06  1.473154e+10    600.943349
# min     2018.000000      1.000000  0.000000e+00  0.000000e+00     84.944283
# 25%     2018.000000      1.000000  1.031418e+05  1.756668e+08   1554.589051
# 50%     2019.000000      2.000000  3.763065e+05  6.784562e+08   1863.135530
# 75%     2020.000000      3.000000  1.272815e+06  2.377256e+09   2203.083552
# max     2021.000000      4.000000  3.487128e+08  4.444224e+11  11209.980550
#
#        Registered Users     App Opens
# count      1.024800e+04  1.024800e+04
# mean       2.349591e+05  4.807117e+06
# std        4.605978e+05  1.562541e+07
# min        2.200000e+01  0.000000e+00
# 25%        3.619550e+04  0.000000e+00
# 50%        1.067640e+05  6.403025e+05
# ...

# %%
df_State_DeviceData.describe()
# Out:
#               Year      Quarter  Registered Users   Percentage
# count  5544.000000  5544.000000      5.544000e+03  5544.000000
# mean   2019.285714     2.357143      4.343183e+05     0.090909
# std       1.030250     1.108970      9.056069e+05     0.083095
# min    2018.000000     1.000000      1.000000e+01     0.006373
# 25%    2018.000000     1.000000      8.055750e+03     0.021588
# 50%    2019.000000     2.000000      7.442250e+04     0.056914
# 75%    2020.000000     3.000000      3.978875e+05     0.143626
# max    2021.000000     4.000000      9.764252e+06     0.478367

# %%
df_State_Txn_and_Users.describe()
# Out:
#               Year     Quarter  Transactions  Amount (INR)    ATV (INR)  \
# count   504.000000  504.000000  5.040000e+02  5.040000e+02   504.000000
# mean   2019.285714    2.357143  4.074000e+07  7.083332e+10  1993.471543
# std       1.031181    1.109971  8.228714e+07  1.439469e+11   607.464894
# min    2018.000000    1.000000  7.780000e+02  1.928611e+06     0.000000
# 25%    2018.000000    1.000000  5.925578e+05  1.171833e+09  1598.910667
# 50%    2019.000000    2.000000  6.217487e+06  1.057102e+10  1861.380589
# 75%    2020.000000    3.000000  4.363675e+07  6.978343e+10  2259.087924
# max    2021.000000    4.000000  5.736165e+08  1.027958e+12  3938.733850
#
#        Registered Users     App Opens
# count      5.040000e+02  5.040000e+02
# mean       4.777501e+06  9.774471e+07
# std        6.644496e+06  2.042376e+08
# min        5.010000e+02  0.000000e+00
# 25%        1.574202e+05  0.000000e+00
# 50%        1.747914e+06  2.930574e+06
# 75%        7.320945e+06  8.615022e+07
# ...

# %%
df_District_Demographics
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
df_District_Demographics.groupby('State').count().reset_index()
# Out:
#                                    State  District  Headquarters  Population  \
# 0              Andaman & Nicobar Islands         3             3           3
# 1                         Andhra Pradesh        13            13          13
# 2                      Arunachal Pradesh        25            25          25
# 3                                  Assam        34            34          34
# 4                                  Bihar        38            38          38
# 5                             Chandigarh         1             1           1
# 6                           Chhattisgarh        28            28          28
# 7   Dadra & Nagar Haveli and Daman & Diu         3             3           3
# 8                                  Delhi        11            11          11
# 9                                    Goa         2             2           2
# 10                               Gujarat        33            33          33
# ...

# %%
df_District_Demographics.groupby('District').count().reset_index()
# Out:
#          District  State  Headquarters  Population  Area (sq km)  Density  \
# 0        Adilabad      1             1           1             1        1
# 1      Agar Malwa      1             1           1             1        1
# 2            Agra      1             1           1             1        1
# 3       Ahmedabad      1             1           1             1        1
# 4      Ahmednagar      1             1           1             1        1
# ..            ...    ...           ...         ...           ...      ...
# 731        Yadgir      1             1           1             1        1
# 732  Yamuna Nagar      1             1           1             1        1
# 733         Yanam      1             1           1             1        1
# 734      Yavatmal      1             1           1             1        1
# 735     Zunheboto      1             1           1             1        1
#
#      Code  Alternate Name
# 0       1               1
# ...

# %%
total_districts=df_District_Demographics['District'].nunique()

# %%
total_states = df_District_Demographics['State'].nunique()

# %%
number_of_dis_per_state=df_District_Demographics.groupby('State')['District'].nunique()

# %%
number_of_dis_per_state=number_of_dis_per_state.sort_values(ascending=False)

# %%
number_of_dis_per_state.idxmax()
# Out:
# 'Uttar Pradesh'

# %%
number_of_dis_per_state.idxmin()
# Out:
# 'Chandigarh'

# %%
df_State_Txn_and_Users.head(20)
# Out:
#                         State  Year  Quarter  Transactions  Amount (INR)  \
# 0   Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1   Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2   Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3   Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4   Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# 5   Andaman & Nicobar Islands  2019        2         33689  1.202547e+08
# 6   Andaman & Nicobar Islands  2019        3         33770  1.140718e+08
# 7   Andaman & Nicobar Islands  2019        4         35159  1.368385e+08
# 8   Andaman & Nicobar Islands  2020        1         41298  1.614763e+08
# 9   Andaman & Nicobar Islands  2020        2         62962  1.696450e+08
# 10  Andaman & Nicobar Islands  2020        3        117483  3.380194e+08
# 11  Andaman & Nicobar Islands  2020        4        224531  6.272827e+08
# ...

# %%
number_of_trans_per_year_by_state=df_State_Txn_and_Users.groupby(['State','Year'])[['Transactions']].sum().reset_index()

# %%
total_amount_per_year_by_state=df_State_Txn_and_Users.groupby(['State','Year'])[['Amount (INR)']].sum().reset_index()

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens categorised_column
# ...

# %%
df_State_DeviceData
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
df_State_TxnSplit
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018        1         Merchant payments
# 3     Andaman & Nicobar Islands  2018        1        Financial Services
# 4     Andaman & Nicobar Islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
top_5_low_trans_by_state=number_of_trans_per_year_by_state.groupby('State')['Transactions'].sum().sort_values().head(5)

# %%
top_5_high_trans_by_state=number_of_trans_per_year_by_state.groupby('State')['Transactions'].sum().sort_values().tail(5)

# %%
df_State_TxnSplit
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018        1         Merchant payments
# 3     Andaman & Nicobar Islands  2018        1        Financial Services
# 4     Andaman & Nicobar Islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
trans_type_for_each_quat_by_state=df_State_TxnSplit.groupby(['State','Quarter'])[['Transaction Type']].value_counts().reset_index()

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens categorised_column
# ...

# %%
df_State_DeviceData
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
total_num_of_user_in_state_by_brands=df_State_DeviceData.groupby(['Brand','State'])[['Registered Users']].sum().reset_index()

# %%
number_of_brands=df_State_DeviceData[['Brand']].nunique()

# %%
highest_users_per_brand_in_state=df_State_DeviceData.groupby(['State','Brand'])[['Registered Users']].sum().reset_index().sort_values(ascending=False,by=['Brand','Registered Users'])

# %%
highest_users_per_brand_in_state
# Out:
#                          State   Brand  Registered Users
# 253                Maharashtra  Xiaomi          80281858
# 421              Uttar Pradesh  Xiaomi          64303360
# 193                  Karnataka  Xiaomi          52595345
# 22              Andhra Pradesh  Xiaomi          40061549
# 393                  Telangana  Xiaomi          38954882
# ..                         ...     ...               ...
# 307                     Odisha   Apple             24617
# 282                    Mizoram   Apple             20441
# 205                     Ladakh   Apple             13863
# 0    Andaman & Nicobar Islands   Apple              9334
# 217                Lakshadweep   Apple               989
#
# [448 rows x 3 columns]

# %%
idx_of_AN=(df_District_Demographics['State']=='Andaman & Nicobar Islands').idxmax()

# %%
total_no_of_app_open=df_State_Txn_and_Users.groupby(['State','Year'])[['App Opens']].sum()

# %%
total_no_of_app_open=total_no_of_app_open.reset_index()

# %%
total_no_of_app_open[['State','App Opens','Year']].max()
# Out:
# State        West Bengal
# App Opens     2746192013
# Year                2021
# dtype: object

# %%
total_no_of_app_open.groupby('Year')['App Opens'].sum()
# Out:
# Year
# 2018              0
# 2019     8669826921
# 2020    22327454991
# 2021    18266049523
# Name: App Opens, dtype: int64

# %%
df_state=total_no_of_app_open[total_no_of_app_open['State'] == 'West Bengal']

# %%
yearly_opens = df_state.groupby("Year")["App Opens"].sum().reset_index()

# %%
yearly_opens
# Out:
#    Year  App Opens
# 0  2018          0
# 1  2019  470399825
# 2  2020  943934300
# 3  2021  592174140

# %%
plt.figure(figsize=(5,4))
plt.plot(yearly_opens['Year'],yearly_opens['App Opens'], marker='o')
plt.xlabel("Year")
plt.ylabel('Number of app opens per year (in 100 millions)')
plt.xticks(np.arange(2018,2022,step=1))
plt.title('App opens over the years in West Bengal')
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
df_state_1=total_no_of_app_open[total_no_of_app_open['State'] == 'Maharashtra']

# %%
df_state_1
# Out:
#           State  Year   App Opens
# 80  Maharashtra  2018           0
# 81  Maharashtra  2019  1093620230
# 82  Maharashtra  2020  2741705251
# 83  Maharashtra  2021  2310060076

# %%
df_state_1
# Out:
#           State  Year   App Opens
# 80  Maharashtra  2018           0
# 81  Maharashtra  2019  1093620230
# 82  Maharashtra  2020  2741705251
# 83  Maharashtra  2021  2310060076

# %%
yearly_opens_1=df_state_1.groupby('Year')[['App Opens']].sum()

# %%
yearly_opens_1=yearly_opens_1.reset_index()

# %%
yearly_opens_1
# Out:
#    Year   App Opens
# 0  2018           0
# 1  2019  1093620230
# 2  2020  2741705251
# 3  2021  2310060076

# %%
plt.figure(figsize=(10,4))
plt.plot(yearly_opens_1['Year'],yearly_opens_1['App Opens'],marker = 'o',color='r',label='Maharashtra')
plt.plot(yearly_opens['Year'],yearly_opens['App Opens'], marker='s',label='West Bengal')

plt.ylabel('Number of app opens (in 100 millions)')
plt.xlabel('Year')
plt.xticks(np.arange(2018,2022,step=1))
plt.title('Phone Pe App opens over the years')
plt.grid(axis='y', linestyle='--',linewidth=0.5)
plt.legend()
plt.show()

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens categorised_column
# ...

# %%
state_wise_district=df_District_Demographics.groupby(['State','District'])[['Population']].sum().reset_index()

# %%
df_District_Demographics.groupby(['District','State'])[['Population']].max().reset_index()
# Out:
#          District           State  Population
# 0        Adilabad       Telangana      708952
# 1      Agar Malwa  Madhya Pradesh      571275
# 2            Agra   Uttar Pradesh     4380793
# 3       Ahmedabad         Gujarat     7208200
# 4      Ahmednagar     Maharashtra     4543083
# ..            ...             ...         ...
# 737        Yadgir       Karnataka     1172985
# 738  Yamuna Nagar         Haryana     1214162
# 739         Yanam      Puducherry       55626
# 740      Yavatmal     Maharashtra     2775457
# 741     Zunheboto        Nagaland      141014
#
# [742 rows x 3 columns]

# %%
df_2=state_wise_district.groupby(['State'])[['Population']].max()

# %%
df_2=df_2.reset_index()

# %%
df_2
# Out:
#                                    State  Population
# 0              Andaman & Nicobar Islands      238142
# 1                         Andhra Pradesh     5151549
# 2                      Arunachal Pradesh      176385
# 3                                  Assam     2826006
# 4                                  Bihar     5772804
# 5                             Chandigarh     1055450
# 6                           Chhattisgarh     2160876
# 7   Dadra & Nagar Haveli and Daman & Diu      343709
# 8                                  Delhi     3656539
# 9                                    Goa      817761
# 10                               Gujarat     7208200
# 11                               Haryana     1798954
# 12                      Himachal Pradesh     1507223
# 13                       Jammu & Kashmir     1526406
# 14                             Jharkhand     2912022
# 15                             Karnataka     9588910
# 16                                Kerala     4110956
# ...

# %%
df_3=df_District_Demographics.merge(df_2,on='Population')

# %%
df_3=df_3.loc[:,:'Population']

# %%
df_3=df_3.rename(columns={'State_x':'State'})

# %%
df_3
# Out:
#                                    State                District Headquarters  \
# 0                         Andhra Pradesh           East Godavari     Kakinada
# 1                      Arunachal Pradesh              Papum Pare        Yupia
# 2                                  Assam                  Nagaon       Nagaon
# 3                                  Bihar                   Patna        Patna
# 4                           Chhattisgarh                  Raipur       Raipur
# 5                                    Goa               North Goa       Panaji
# 6                                Gujarat               Ahmedabad    Ahmedabad
# 7                                Haryana               Faridabad    Faridabad
# 8                       Himachal Pradesh                  Kangra  Dharamshala
# 9                              Jharkhand                  Ranchi       Ranchi
# 10                             Karnataka         Bangalore Urban    Bangalore
# ...

# %%
plt.figure(figsize=(10,13))
plt.bar(df_3['State'],df_3['Population'],color='c')
for i, (State, Population, District) in enumerate(zip(df_3['State'],df_3['Population'], df_3['District'])):
    plt.text(i, Population + 20000, District, ha='center', fontsize=10)
plt.title("District with Highest Population in Each State")
plt.xlabel("State")
plt.ylabel("Population (in 10 millions)")
plt.xticks(rotation=90)
plt.yticks(np.arange(50000,10000000,step=500000))
plt.tight_layout()
plt.show()

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens categorised_column
# ...

# %%
state_wise_avg_trans=df_State_Txn_and_Users.groupby('State')['Transactions'].mean()

# %%
state_wise_avg_trans=state_wise_avg_trans.reset_index()

# %%
state_wise_avg_trans.sort_values('State',ascending=True)
# Out:
#                                    State  Transactions
# 0              Andaman & Nicobar Islands  8.739750e+04
# 1                         Andhra Pradesh  1.272208e+08
# 2                      Arunachal Pradesh  5.745571e+05
# 3                                  Assam  8.826999e+06
# 4                                  Bihar  5.097456e+07
# 5                             Chandigarh  1.822610e+06
# 6                           Chhattisgarh  1.727918e+07
# 7   Dadra & Nagar Haveli and Daman & Diu  8.901561e+05
# 8                                  Delhi  7.221651e+07
# 9                                    Goa  1.748686e+06
# 10                               Gujarat  4.378520e+07
# 11                               Haryana  4.055367e+07
# 12                      Himachal Pradesh  3.784818e+06
# 13                       Jammu & Kashmir  3.218095e+06
# 14                             Jharkhand  1.966221e+07
# 15                             Karnataka  2.129318e+08
# ...

# %%
State_wise_ATV=df_State_Txn_and_Users.groupby('State')[['ATV (INR)']].sum()

# %%
State_wise_ATV=State_wise_ATV.reset_index()

# %%
State_wise_ATV=State_wise_ATV.sort_values('ATV (INR)',ascending=True)

# %%
state_with_highest_5_ATV=State_wise_ATV.tail(5)[::-1]

# %%
state_with_lowest_5_ATV=State_wise_ATV.head(5)[::-1]

# %%
state_with_lowest_5_ATV
# Out:
#                                    State     ATV (INR)
# 15                             Karnataka  21243.491492
# 20                           Maharashtra  21229.065480
# 7   Dadra & Nagar Haveli and Daman & Diu  20823.538391
# 25                                Odisha  19993.923141
# 35                           West Bengal  19230.408260

# %%
state_with_highest_5_ATV
# Out:
#                         State     ATV (INR)
# 17                     Ladakh  47715.121781
# 0   Andaman & Nicobar Islands  44229.729913
# 23                    Mizoram  40985.249221
# 18                Lakshadweep  38865.661810
# 2           Arunachal Pradesh  36936.535789

# %%
plt.figure(figsize=(8,6))
plt.bar(state_with_highest_5_ATV['State'],state_with_highest_5_ATV['ATV (INR)'],color='c')
plt.xticks(rotation = 90)
plt.title('Top 5 states with highest total ATV')
plt.xlabel('States',color='r')
plt.ylabel('ATV (Average Transaction Value)',color='r')
plt.grid(axis='y',linestyle='--')

# %%
plt.figure(figsize=(8,6))
plt.bar(state_with_lowest_5_ATV['State'],state_with_lowest_5_ATV['ATV (INR)'],color='b')
plt.xticks(rotation = 90)
plt.title('Top 5 states with lowest total ATV')
plt.xlabel('States',color='r')
plt.ylabel('ATV (Average Transaction Value)',color='r')
plt.grid(axis='y',linestyle='--')

# %%
df_State_Txn_and_Users.groupby(['State','Quarter'])['']
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens categorised_column
# ...

# %%
df_District_Txn_and_Users
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...

# %%
latest_year=df_State_TxnSplit['Year'].max()

# %%
latest_quarter = df_State_TxnSplit[df_State_TxnSplit['Year']==latest_year]['Quarter'].max()

# %%
latest_quarter
# Out:
# 2

# %%
latest_year
# Out:
# 2021

# %%
recent_data=df_State_TxnSplit[(df_State_TxnSplit['Year']==latest_year)&(df_State_TxnSplit['Quarter']==latest_quarter)]

# %%
recent_data
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 65    Andaman & Nicobar Islands  2021        2     Peer-to-peer payments
# 66    Andaman & Nicobar Islands  2021        2  Recharge & bill payments
# 67    Andaman & Nicobar Islands  2021        2         Merchant payments
# 68    Andaman & Nicobar Islands  2021        2        Financial Services
# 69    Andaman & Nicobar Islands  2021        2                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
recent_data=recent_data.groupby(['State','Transaction Type'])[['Transactions']].sum()

# %%
recent_data=recent_data.reset_index()

# %%
recent_data.sort_values('Transactions')
# Out:
#                          State       Transaction Type  Transactions
# 90                 Lakshadweep     Financial Services            29
# 92                 Lakshadweep                 Others            44
# 115                    Mizoram     Financial Services           611
# 85                      Ladakh     Financial Services           755
# 0    Andaman & Nicobar Islands     Financial Services           960
# ..                         ...                    ...           ...
# 78                   Karnataka  Peer-to-peer payments     216539959
# 103                Maharashtra  Peer-to-peer payments     228551961
# 158                  Telangana  Peer-to-peer payments     230861833
# 76                   Karnataka      Merchant payments     244460862
# 101                Maharashtra      Merchant payments     247194293
#
# [180 rows x 3 columns]

# %%
import seaborn as sns

# %%
plt.figure(figsize=(16,9))
sns.barplot(data=recent_data,x='State',y='Transactions',hue='Transaction Type')
plt.xticks(rotation=90)
plt.yticks()
plt.title(f"Distribution of Transaction Types for Each State - Q{latest_quarter},{latest_year}")
plt.tight_layout()
plt.show()

# %%
df_District_Demographics
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
district_code_per_state=dff.groupby(['State','District','Code'])[['Population']].sum()

# %%
district_code_per_state=district_code_per_state.reset_index()

# %%
del district_code_per_state['Population']

# %%
district_code_per_state.to_csv('output.csv',index=False)

# %%
district_code_per_state
# Out:
#                          State                  District  Code
# 0    Andaman & Nicobar Islands                   Nicobar  AN01
# 1    Andaman & Nicobar Islands  North and Middle Andaman  AN02
# 2    Andaman & Nicobar Islands             South Andaman  AN03
# 3               Andhra Pradesh                 Anantapur  AP01
# 4               Andhra Pradesh                  Chittoor  AP02
# ..                         ...                       ...   ...
# 737                West Bengal           Purba Bardhaman  WB19
# 738                West Bengal           Purba Medinipur  WB20
# 739                West Bengal                   Purulia  WB21
# 740                West Bengal         South 24 Parganas  WB22
# 741                West Bengal            Uttar Dinajpur  WB23
#
# [742 rows x 3 columns]

# %%
df_District_Txn_and_Users
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...

# %%
total_trans_amount_reg_users=df_District_Txn_and_Users.groupby('State')[['Transactions','Amount (INR)','Registered Users']].sum()

# %%
total_trans_amount_reg_users=total_trans_amount_reg_users.reset_index()

# %%
total_trans_amount_reg_users
# Out:
#                                    State  Transactions  Amount (INR)  \
# 0              Andaman & Nicobar Islands       1223565  3.641818e+09
# 1                         Andhra Pradesh    1781091169  3.860292e+12
# 2                      Arunachal Pradesh       8043799  2.225183e+10
# 3                                  Assam     123577981  2.814087e+11
# 4                                  Bihar     713643889  1.639579e+12
# 5                             Chandigarh      25516542  5.371208e+10
# 6                           Chhattisgarh     241908549  4.156353e+11
# 7   Dadra & Nagar Haveli and Daman & Diu      12462185  1.865878e+10
# 8                                  Delhi    1011031124  1.649942e+12
# 9                                    Goa      24481604  4.427187e+10
# 10                               Gujarat     612992823  1.105329e+12
# 11                               Haryana     567751410  1.059832e+12
# 12                      Himachal Pradesh      52987445  9.786546e+10
# ...

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens categorised_column
# ...

# %%
df_4=df_State_Txn_and_Users.groupby('State')[['Transactions','Amount (INR)','Registered Users']].sum()

# %%
df_4=df_4.reset_index()

# %%
df_4.equals(total_trans_amount_reg_users)
# Out:
# False

# %%
df_4.dtypes
# Out:
# State               object
# Transactions         int64
# Amount (INR)         int64
# Registered Users     int64
# dtype: object

# %%
total_trans_amount_reg_users.dtypes
# Out:
# State               object
# Transactions         int64
# Amount (INR)         int64
# Registered Users     int64
# dtype: object

# %%
total_trans_amount_reg_users==df_4
# Out:
#     State  Transactions  Amount (INR)  Registered Users
# 0    True          True          True              True
# 1    True          True         False              True
# 2    True          True          True              True
# 3    True          True          True              True
# 4    True          True          True              True
# 5    True          True          True              True
# 6    True          True          True              True
# 7    True          True          True              True
# 8    True          True          True              True
# 9    True          True          True              True
# 10   True          True          True              True
# 11   True          True          True              True
# 12   True          True          True              True
# 13   True          True          True              True
# 14   True          True          True              True
# 15   True          True          True              True
# ...

# %%
df_4
# Out:
#                                    State  Transactions   Amount (INR)  \
# 0              Andaman & Nicobar Islands       1223565     3641817860
# 1                         Andhra Pradesh    1781091169  3258680789453
# 2                      Arunachal Pradesh       8043799    22251830956
# 3                                  Assam     123577981   281408712657
# 4                                  Bihar     713643889  1639578926751
# 5                             Chandigarh      25516542    53712084630
# 6                           Chhattisgarh     241908549   415635319208
# 7   Dadra & Nagar Haveli and Daman & Diu      12462185    18658784568
# 8                                  Delhi    1011031124  1649942211116
# 9                                    Goa      24481604    44271871113
# 10                               Gujarat     612992823  1105328681946
# 11                               Haryana     567751410  1059831565199
# ...

# %%
total_trans_amount_reg_users
# Out:
#                                    State  Transactions   Amount (INR)  \
# 0              Andaman & Nicobar Islands       1223565     3641817860
# 1                         Andhra Pradesh    1781091169  3860292139028
# 2                      Arunachal Pradesh       8043799    22251830956
# 3                                  Assam     123577981   281408712657
# 4                                  Bihar     713643889  1639578926751
# 5                             Chandigarh      25516542    53712084630
# 6                           Chhattisgarh     241908549   415635319208
# 7   Dadra & Nagar Haveli and Daman & Diu      12462185    18658784568
# 8                                  Delhi    1011031124  1649942211116
# 9                                    Goa      24481604    44271871113
# 10                               Gujarat     612992823  1105328681946
# 11                               Haryana     567751410  1059831565199
# ...

# %%
# df_State_Txn_and_Users have 3258680789453 total amount in andhra pradesh on state level 
# while df_District_Txn_and_Users have 3860292139028 total amount in andhra pradesh on district level

# %%
plt.plot(df_4['State'],df_4['Amount (INR)'],marker = 'o',color = 'r',label='State level',linewidth=2.5)
plt.plot(total_trans_amount_reg_users['State'],total_trans_amount_reg_users['Amount (INR)'],marker='s',label='District level',color='c')
plt.xticks(rotation = 90)
plt.legend()
plt.ylabel('Total amount  (in 100 millions) ',color='b')
plt.xlabel('State',color='b')
plt.grid(axis='y',linestyle='--')
plt.show()

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
df_District_Demographics
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
merged_df=df_State_Txn_and_Users.merge(df_District_Demographics,on='State')

# %%
tru_tp_df=merged_df.groupby('State').agg(total_registered_users=('Registered Users','sum'),total_population=('Population','sum'))

# %%
tru_tp_df=tru_tp_df.reset_index()

# %%
tru_tp_df['user_to_population'] = tru_tp_df['total_registered_users']/tru_tp_df['total_population']

# %%
tru_tp_df
# Out:
#                                    State  total_registered_users  \
# 0              Andaman & Nicobar Islands                 1225188
# 1                         Andhra Pradesh              2054103441
# 2                      Arunachal Pradesh                46555350
# 3                                  Assam               913265534
# 4                                  Bihar              4380820880
# 5                             Chandigarh                 3801466
# 6                           Chhattisgarh              1048554864
# 7   Dadra & Nagar Haveli and Daman & Diu                 8103336
# 8                                  Delhi              1049121194
# 9                                    Goa                 9510640
# 10                               Gujarat              4170541056
# 11                               Haryana              1882410618
# 12                      Himachal Pradesh               160487760
# ...

# %%
plt.figure(figsize=(10,6))
plt.bar(tru_tp_df['State'],tru_tp_df['user_to_population'],color='c')
plt.xticks(rotation=90)
plt.yticks(np.arange(0,11,1))
plt.xlabel('State',color='b')
plt.ylabel('Ratio',color='b')
plt.title('User to Population ratio')
plt.grid(axis='y',linestyle='--',linewidth=0.85)
plt.show()

# %%
df_District_Txn_and_Users
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...

# %%
df_District_Demographics
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
m_df=df_District_Demographics.merge(df_District_Txn_and_Users,on='District')

# %%
m_df
# Out:
#              State_x   District Headquarters  Population  Area (sq km)  \
# 0     Andhra Pradesh  Anantapur    Anantapur     4083315       19130.0
# 1     Andhra Pradesh  Anantapur    Anantapur     4083315       19130.0
# 2     Andhra Pradesh  Anantapur    Anantapur     4083315       19130.0
# 3     Andhra Pradesh  Anantapur    Anantapur     4083315       19130.0
# 4     Andhra Pradesh  Anantapur    Anantapur     4083315       19130.0
# ...              ...        ...          ...         ...           ...
# 8941      Puducherry      Yanam        Yanam       55626          30.0
# 8942      Puducherry      Yanam        Yanam       55626          30.0
# 8943      Puducherry      Yanam        Yanam       55626          30.0
# 8944      Puducherry      Yanam        Yanam       55626          30.0
# 8945      Puducherry      Yanam        Yanam       55626          30.0
#
#       Density Code_x Alternate Name         State_y  Year  Quarter Code_y  \
# ...

# %%
m_df['ATV (INR)'].corr(m_df['Density'])
# Out:
# -0.05036464578100155

# %%
m_df[['ATV (INR)','Density']].corr()
# Out:
#            ATV (INR)   Density
# ATV (INR)   1.000000 -0.050365
# Density    -0.050365  1.000000

# %%
plt.figure(figsize=(8,6))
plt.scatter(x='ATV (INR)',y='Density',data=m_df)
plt.title('ATV (INR) vs Density')
plt.xlabel('ATV (INR)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# %%
sns.regplot(y='ATV (INR)',x='Density',data=m_df,line_kws={'color':'red'},scatter_kws={'color':'skyblue'})
plt.grid(True)
plt.title('Transaction Volume vs Density')
plt.show()
# negative

# %%
"""
The scatter plot between transaction volume and population density shows a negative correlation, 
indicating that as population density increases, 
the transaction volume tends to decrease.
This suggests that highly dense areas may have lower digital transaction activity, possibly due to:

#Limited access to digital infrastructure,

#Cash-dominant economies,

#Lower digital literacy in crowded or underserved regions.
"""
# Out:
# '\nThe scatter plot between transaction volume and population density shows a negative correlation, \nindicating that as population density increases, \nthe transaction volume tends to decrease.\nThis suggests that highly dense areas may have lower digital transaction activity, possibly due to:\n\n#Limited access to digital infrastructure,\n\n#Cash-dominant economies,\n\n#Lower digital literacy in crowded or underserved regions.\n'

# %%
df_State_Txn_and_Users
# Out:
#                          State  Year  Quarter  Transactions  Amount (INR)  \
# 0    Andaman & Nicobar Islands  2018        1          6658  1.463176e+07
# 1    Andaman & Nicobar Islands  2018        2         11340  2.833854e+07
# 2    Andaman & Nicobar Islands  2018        3         16265  5.555747e+07
# 3    Andaman & Nicobar Islands  2018        4         23758  9.054834e+07
# 4    Andaman & Nicobar Islands  2019        1         30486  1.022997e+08
# ..                         ...   ...      ...           ...           ...
# 499                West Bengal  2020        2      57676797  1.000994e+11
# 500                West Bengal  2020        3      79954504  1.568134e+11
# 501                West Bengal  2020        4     100340645  1.991655e+11
# 502                West Bengal  2021        1     118254052  2.429372e+11
# 503                West Bengal  2021        2     141897437  2.794348e+11
#
#        ATV (INR)  Registered Users  App Opens
# ...

# %%
merged_df=df_State_Txn_and_Users.groupby('State')[['Amount (INR)','Registered Users']].sum()

# %%
merged_df=merged_df.reset_index()

# %%
merged_df['trans_amount_per_uesr'] = merged_df['Amount (INR)']/merged_df['Registered Users']

# %%
top_5_highest_state_trans_amount_per_uesr=merged_df.sort_values('trans_amount_per_uesr',ascending=False).head(5)

# %%
top_5_lowest_state_trans_amount_per_uesr=merged_df.sort_values('trans_amount_per_uesr').head(5)

# %%
top_5_highest_state_trans_amount_per_uesr
# Out:
#              State  Amount (INR)  Registered Users  trans_amount_per_uesr
# 31       Telangana  4.574246e+12         149224214           30653.509622
# 15       Karnataka  4.361396e+12         203098564           21474.282206
# 1   Andhra Pradesh  3.187847e+12         158007957           20175.233763
# 28       Rajasthan  2.625584e+12         149770064           17530.768707
# 8            Delhi  1.649942e+12          95374654           17299.587909

# %%
top_5_lowest_state_trans_amount_per_uesr
# Out:
#                                    State  Amount (INR)  Registered Users  \
# 18                           Lakshadweep  1.921587e+08             34223
# 32                               Tripura  2.097051e+10           3661575
# 7   Dadra & Nagar Haveli and Daman & Diu  1.865878e+10           2701112
# 16                                Kerala  3.729599e+11          51267042
# 12                      Himachal Pradesh  9.786546e+10          13373980
#
#     trans_amount_per_uesr
# 18            5614.898889
# 32            5727.184275
# 7             6907.815954
# 16            7274.846690
# 12            7317.601442

# %%
df_State_DeviceData.groupby('State')[['Registered Users']].sum()
# Out:
#                                       Registered Users
# State
# Andaman & Nicobar Islands                       408396
# Andhra Pradesh                               158007957
# Arunachal Pradesh                              1862214
# Assam                                         26860751
# Bihar                                        115284760
# Chandigarh                                     3801466
# Chhattisgarh                                  37448388
# Dadra & Nagar Haveli and Daman & Diu           2701112
# Delhi                                         95374654
# Goa                                            4755320
# Gujarat                                      126380032
# Haryana                                       85564119
# Himachal Pradesh                              13373980
# Jammu & Kashmir                                9756438
# Jharkhand                                     44768682
# Karnataka                                    203098564
# ...

# %%
df_1=m_df_2.groupby(['State'])[['Registered Users_x']].sum().reset_index()

# %%
df_2=m_df_2.groupby(['State','Brand'])[['Registered Users_x']].sum().reset_index()

# %%
df_1=df_1.rename(columns={'Registered Users_x':'Total_Registered Users'})

# %%
df_2=df_2.rename(columns={'Registered Users_x':'Registered Users'})

# %%
df_1
# Out:
#                                    State  Total_Registered Users
# 0              Andaman & Nicobar Islands                  408396
# 1                         Andhra Pradesh               158007957
# 2                      Arunachal Pradesh                 1862214
# 3                                  Assam                26860751
# 4                                  Bihar               115284760
# 5                             Chandigarh                 3801466
# 6                           Chhattisgarh                37448388
# 7   Dadra & Nagar Haveli and Daman & Diu                 2701112
# 8                                  Delhi                95374654
# 9                                    Goa                 4755320
# 10                               Gujarat               126380032
# 11                               Haryana                85564119
# 12                      Himachal Pradesh                13373980
# ...

# %%
merged_df=df_1.merge(df_2,on='State',how='right')

# %%
merged_df['Ratio (RU to TRU)'] = merged_df['Registered Users']/merged_df['Total_Registered Users']

# %%
merged_df
# Out:
#                          State  Total_Registered Users     Brand  \
# 0    Andaman & Nicobar Islands                  408396     Apple
# 1    Andaman & Nicobar Islands                  408396    Huawei
# 2    Andaman & Nicobar Islands                  408396    Lenovo
# 3    Andaman & Nicobar Islands                  408396  Motorola
# 4    Andaman & Nicobar Islands                  408396   OnePlus
# ..                         ...                     ...       ...
# 443                West Bengal               144242183    Others
# 444                West Bengal               144242183    Realme
# 445                West Bengal               144242183   Samsung
# 446                West Bengal               144242183      Vivo
# 447                West Bengal               144242183    Xiaomi
#
#      Registered Users  Ratio (RU to TRU)
# 0                9334           0.022855
# 1               11497           0.028152
# 2                5362           0.013129
# ...

# %%
df_State_DeviceData
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
plt.bar(merged_df['Brand'],merged_df['Ratio (RU to TRU)'])
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='State',y='Ratio (RU to TRU)',hue='Brand',data=merged_df)
plt.xticks(rotation = 90)
plt.yticks(np.arange(0.01,0.5,step=0.1))
plt.title('Ratio of registered to total registered users in each state')
plt.grid(axis='y',linestyle='--',linewidth=1.85)
plt.show()

# %%
result_df=df_State_TxnSplit.groupby(['State','Year','Quarter'])[['Transactions','Amount (INR)']].sum().reset_index()

# %%
up_df=result_df[result_df['State']=='Uttar Pradesh']

# %%
up_df
# Out:
#              State  Year  Quarter  Transactions  Amount (INR)
# 462  Uttar Pradesh  2018        1      12537805  1.393997e+10
# 463  Uttar Pradesh  2018        2      17710943  2.572020e+10
# 464  Uttar Pradesh  2018        3      26515356  3.701211e+10
# 465  Uttar Pradesh  2018        4      36100767  5.509674e+10
# 466  Uttar Pradesh  2019        1      57324504  7.652418e+10
# 467  Uttar Pradesh  2019        2      58883500  9.891752e+10
# 468  Uttar Pradesh  2019        3      68623959  1.112681e+11
# 469  Uttar Pradesh  2019        4      86905005  1.455389e+11
# 470  Uttar Pradesh  2020        1      97239132  1.724164e+11
# 471  Uttar Pradesh  2020        2     100851965  1.787440e+11
# 472  Uttar Pradesh  2020        3     127405259  2.486900e+11
# 473  Uttar Pradesh  2020        4     178167517  3.574288e+11
# 474  Uttar Pradesh  2021        1     204499547  3.962876e+11
# 475  Uttar Pradesh  2021        2     241949131  4.821725e+11

# %%
up_df['Year_Quarter']=up_df['Year'].astype(str)+'-Q'+ up_df['Quarter'].astype(str)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15600\630320196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   up_df['Year_Quarter']=up_df['Year'].astype(str)+'-Q'+ up_df['Quarter'].astype(str)

# %%
plt.figure(figsize=(10,6))

plt.plot(up_df['Year_Quarter'],up_df['Transactions'],color='r')
plt.xticks(rotation=90)

plt.title('Total number of transaction in U.P. over the time')
plt.xlabel('Year and Quarter')
plt.ylabel('Number of Transactions (in 10 millions)' )
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(up_df['Year_Quarter'],up_df['Amount (INR)'],color='orange')
plt.xticks(rotation=90)
plt.title('Total amount in U.P. over the time')
plt.xlabel('Year and Quarter')
plt.ylabel('Amount (in Billions)' )
plt.grid(axis='y')
plt.show()

# %%
gp_df=df_District_Demographics.groupby(['State','District'])[['Density']].sum().reset_index()

# %%
WB_df=gp_df[gp_df['State']=='West Bengal']

# %%
WB_df
# Out:
#            State           District  Density
# 719  West Bengal         Alipurduar      479
# 720  West Bengal            Bankura      523
# 721  West Bengal            Birbhum      771
# 722  West Bengal        Cooch Behar      833
# 723  West Bengal   Dakshin Dinajpur      753
# 724  West Bengal         Darjeeling      762
# 725  West Bengal            Hooghly     1753
# 726  West Bengal             Howrah     3300
# 727  West Bengal         Jalpaiguri      621
# 728  West Bengal           Jhargram      374
# 729  West Bengal          Kalimpong      239
# 730  West Bengal            Kolkata    24252
# 731  West Bengal             Maldah     1071
# 732  West Bengal        Murshidabad     1334
# 733  West Bengal              Nadia     1316
# 734  West Bengal  North 24 Parganas     2463
# 735  West Bengal  Paschim Bardhaman     1798
# 736  West Bengal  Paschim Medinipur      757
# 737  West Bengal    Purba Bardhaman      890
# 738  West Bengal    Purba Medinipur     1076
# ...

# %%
plt.figure(figsize=(15,8))
plt.bar(WB_df['District'],WB_df['Density'],color='#ad4c2f')
plt.xticks(rotation=90)
plt.xlabel('District',fontsize=18,color='#1c8c34')
plt.ylabel('Density',fontsize=18,color='#1c8c34')
plt.title('Density in different districts of West Bengal',fontsize=20,color='#0d4039')
plt.yticks(np.arange(1000,25001,1500))
plt.grid(axis='y',linestyle='--')
plt.show()

# %%
df_State_TxnSplit
# Out:
#                           State  Year  Quarter          Transaction Type  \
# 0     Andaman & Nicobar Islands  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar Islands  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar Islands  2018        1         Merchant payments
# 3     Andaman & Nicobar Islands  2018        1        Financial Services
# 4     Andaman & Nicobar Islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 2509                West Bengal  2021        2     Peer-to-peer payments
# 2510                West Bengal  2021        2         Merchant payments
# 2511                West Bengal  2021        2  Recharge & bill payments
# 2512                West Bengal  2021        2        Financial Services
# 2513                West Bengal  2021        2                    Others
#
#       Transactions  Amount (INR)    ATV (INR)
# ...

# %%
df_State_DeviceData
# Out:
#                           State  Year  Quarter    Brand  Registered Users  \
# 0     Andaman & Nicobar Islands  2018        1   Xiaomi              1665
# 1     Andaman & Nicobar Islands  2018        1  Samsung              1445
# 2     Andaman & Nicobar Islands  2018        1     Vivo               982
# 3     Andaman & Nicobar Islands  2018        1     Oppo               501
# 4     Andaman & Nicobar Islands  2018        1  OnePlus               332
# ...                         ...   ...      ...      ...               ...
# 5539                West Bengal  2021        2   Lenovo            350841
# 5540                West Bengal  2021        2     Asus            297579
# 5541                West Bengal  2021        2   Huawei            272965
# 5542                West Bengal  2021        2    Apple            201393
# 5543                West Bengal  2021        2   Others           1928653
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
df_District_Demographics
# Out:
#               State       District    Headquarters  Population  Area (sq km)  \
# 0    Andhra Pradesh      Anantapur       Anantapur     4083315       19130.0
# 1    Andhra Pradesh       Chittoor        Chittoor     4170468       15152.0
# 2    Andhra Pradesh  East Godavari        Kakinada     5151549       10807.0
# 3    Andhra Pradesh         Guntur          Guntur     4889230       11391.0
# 4    Andhra Pradesh            YSR          Kadapa     2884524       15359.0
# ..              ...            ...             ...         ...           ...
# 737           Delhi     West Delhi  Rajouri Garden     2543243         112.0
# 738      Puducherry       Karaikal        Karaikal      200222         157.0
# 739      Puducherry           Mahé            Mahé       41816           9.0
# 740      Puducherry     Puducherry     Pondicherry      950289         293.0
# 741      Puducherry          Yanam           Yanam       55626          30.0
#
#      Density  Code Alternate Name
# ...

# %%
df_District_Txn_and_Users
# Out:
#                            State  Year  Quarter                    District  \
# 0      Andaman & Nicobar Islands  2018        1                    Nicobars
# 1      Andaman & Nicobar Islands  2018        1    North And Middle Andaman
# 2      Andaman & Nicobar Islands  2018        1               South Andaman
# 3      Andaman & Nicobar Islands  2018        2                    Nicobars
# 4      Andaman & Nicobar Islands  2018        2    North And Middle Andaman
# ...                          ...   ...      ...                         ...
# 10243                West Bengal  2021        2             Purba Bardhaman
# 10244                West Bengal  2021        2             Purba Medinipur
# 10245                West Bengal  2021        2                     Purulia
# 10246                West Bengal  2021        2  South Twenty Four Parganas
# 10247                West Bengal  2021        2              Uttar Dinajpur
#
# ...
